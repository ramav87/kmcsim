# %% [markdown]
# # KMC simulation of PLD with Deep Q Learning
#
# In this version the state function is the whole atomic coordinate box

# %%
#!pip install tensorflow keras

# %%
#!pip install tensorflow-gpu

# %%
import sys
import os
import numpy as np
import collections
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from time import time
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
#Writing some helper functions

def write_lattice_to_file(input_settings,position_vec, latt):
    #Write a new input lattice file
    #position_vec is the array containing positions of all of the atoms
    filename = input_settings['incfg_file'][0]
    new_latt_xyzs = list()
    
    for i in range(position_vec.shape[0]):
        new_latt_xyzs.append(list(['Ni', position_vec[i,0], position_vec[i,1],position_vec[i,2]]))

    new_latt = collections.OrderedDict()
    new_latt['nat'] = latt['nat']
    new_latt['box'] = latt['box']
    new_latt['xyzs'] = new_latt_xyzs

    write_latt(new_latt, filename)
    
    return 

def write_new_input_file(input_settings, filename):
    #Write a new input file, with settings laid out in the dictionary input_settings
    
    with open(filename, 'w') as fo:
        for key, val in input_settings.items():
            string_to_write = key + ": " + str(val) +'\n'
            fo.write(string_to_write)

def write_params_file(input_settings, new_parms):
    #IF you want to change parameters, use this function to write a new parameters file
    new_parms_file = input_settings['param_file']
    
    with open(new_parms_file, 'w') as fo:
        for key, val in new_parms.items():
            string_to_write = key + ": " + str(val) +'\n'
            fo.write(string_to_write)
            
def make_surface_proj(atom_box):
    #Given an atom box (matrix with 1s where atoms are), determine the surface projection
    
    surface_proj = np.zeros(shape=(atom_box.shape[0], atom_box.shape[1]))
    for i in range(surface_proj.shape[0]):
        for j in range(surface_proj.shape[1]):
            try:
                surface_proj[i,j] = np.max(np.where(atom_box[i,j,:]==1))
            except ValueError:
                surface_proj[i,j] = 0
    return surface_proj

def calc_roughness(surface_projection):
    #Calculate the roughness, given a surface projection
    N = surface_projection.shape[0]
    M = surface_projection.shape[1]
    zbar = np.mean(surface_projection)
    z_sum = 0
    for i in range(N):
        for j in range(M):
            z_sum+=((surface_projection[i,j] - zbar )**2)
    rms_roughness = np.sqrt((1.0/(N*M))*z_sum)
    return rms_roughness

def get_state_reward(sim_model):
    '''Given an input of the simulation model this function returns the state and reward'''
    #To get the final state put atoms into atom box
    arr = sim_model.kmc.get_conf()
    arr_1 = np.array(arr[0])
    full_atom_box = np.zeros([latt['box'][1],latt['box'][2],latt['box'][3] ])
    for i,j,k in arr_1:
        full_atom_box[i,j,k]=1
        
    surface_proj = make_surface_proj(full_atom_box)
    rms_val = calc_roughness(surface_proj)
    
    return full_atom_box, -1*rms_val

def run_sim_with_chosen_action(s,action,old_rate, new_rates, verbose=False):
    #Given simulation model and the action, update the rate and continue running the simulation
    
    #update the rates based on the action taken
    
    #new_rate = new_rates[action]
    '''if action<4
        new_dep_rate = new_rate
        new_diff_rate = old_rates[0]
    else:
        new_diff_rate = new_rate
        new_dep_rate = old_rates[1]'''
    new_diff_rate = old_rate[1]
    new_dep_rate = new_rates[action]
    
    s.update_rate(np.array([new_dep_rate, new_diff_rate]), verbose=verbose)
    
    end_flag = s.run_to_next_step(random_seed = np.random.randint(1,99))
    
    #Now get the state and reward
    state, reward = get_state_reward(s)
            
    return state, reward, s,end_flag

# %%
#Need to hold the state in memory and hten

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
sys.path.append('..') #/Users/l2v/work/kmcsim

# %% [markdown]
# Import kmc simulation tools

# %%
from kmcsim.buildtools import make_fcc, write_latt
from kmcsim.sim import KMCModel
from kmcsim.sim import EventTree
from kmcsim.sim import RunSim

# %% [markdown]
# Working directory (inputs, outputs)

# %%
wdir = '../data/working'

# %%
#cat ../data/working/params

# %% [markdown]
# Set up simulation box and initial configuration of the substrate (with atoms filling the whole box)

# %%
# make substrate: perfect FCC lattice of given dimensions
box = [16, 32, 4]
latt = make_fcc(box)

# %%
# extend the box in the z-direction to make space for new layers to grow
latt['box'][3] = 12

# %%
# write initial configuration to xyz file in the working directory
write_latt(latt, os.path.join(wdir,'ni.xyz'))

# %%
sim = RunSim()
sim.read(os.path.join(wdir,'kmc.input'))
sim.init_sim()
sim.run()
# Out:
# ('Number of events:', array([512,   0]))
# (30.003099041486053, 3559, 3356)

# %%
drates = [0.12, 0.12, 0.12]
deprates = [0.10, 0.12, 0.14]

arrs = []
roughness_values = []
for k in range(3):

    sim = RunSim()
    sim.read(os.path.join(wdir,'kmc.input'))
    sim.init_sim()
    sim.update_rate(np.array([deprates[k], drates[k]]))
    fig, axes = plt.subplots(figsize = (10,10), nrows=2,ncols=3)
    fig.suptitle("Trial # {}".format(k), fontsize = 18, y = 1.05)
    for ind, ax in enumerate(axes.flat):

        sim.run_to_next_step()
        arr = sim.kmc.get_conf()
        arr_1 = np.array(arr[0])
        arrs.append(arr_1)
        full_atom_box = np.zeros([latt['box'][1],latt['box'][2],latt['box'][3] ])
        for i,j,k in arr_1:
            full_atom_box[i,j,k]=1

        surface_proj = make_surface_proj(full_atom_box)
        rms_val = calc_roughness(surface_proj)
        roughness_values.append(rms_val)
        im1 = ax.imshow(surface_proj)
        #plt.colorbar()
        ax.set_title('RMS: ' + str(np.round(rms_val,2)));
        ax.axis('off')
        #ax.set_yticklabels('')
        
        divider = make_axes_locatable(ax)
        cax = divider.append_axes('right', size='5%', pad=0.05)
        cb = fig.colorbar(im1, cax=cax, orientation='vertical')
        cb.ax.set_ylabel('Height (at. u.)')
        
    fig.tight_layout(h_pad = 1.12, w_pad = 1.12)
# Out:
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.1  0.12]
# ('kmc step:', 0)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)

# %%
colors = plt.cm.get_cmap('viridis', arr_1[:,2].max()*1.25)
arr_1 = arrs[5]

fig2, axes2 = plt.subplots(figsize = (18,12),nrows=2,ncols=3,subplot_kw=dict(projection='3d'))
for ind, ax in enumerate(axes2.flat):
    roughness_val = np.round(roughness_values[ind],2)
    arr_1 = arrs[ind]
    #ax = fig.add_subplot(111, projection='3d')
    ax.scatter(arr_1[:,0],arr_1[:,1],arr_1[:,2],s=88, alpha = 0.7, c = colors(arr_1[:,2]) )
    ax.view_init(40, 45)
    ax.set_xlabel('X', fontsize = 12)
    ax.set_ylabel('Y', fontsize = 12)
    ax.set_zlabel('Z', fontsize = 12)
    ax.set_title('RMS: {}'.format(roughness_val), loc = 'left', fontsize = 18)
fig2.tight_layout()

# %%
time_vec = np.linspace(0,30,5)

fig, axes = plt.subplots(figsize = (6,4))
axes.plot(time_vec, roughness_values[:5], color = 'b', markersize = 4, marker = 'o',label = deprates[0])
axes.plot(time_vec, roughness_values[6:11], color = 'r', markersize = 4, marker = 'o',label = deprates[1])
axes.plot(time_vec, roughness_values[12:-1], color = 'k', markersize = 4, marker = 'o',label = deprates[2])
axes.set_xlabel('Time (s)', fontsize = 18)
axes.set_ylabel('RMS Roughness', fontsize = 18)
fig.legend(loc=[0.2, 0.65], fontsize= 14)
for tickx in axes.xaxis.get_major_ticks():
    tickx.label.set_fontsize(14) 
for ticky in axes.yaxis.get_major_ticks():
    ticky.label.set_fontsize(14) 
axes.set_title('Roughness as Func. of Deposition Rates', fontsize = 16)
# Out:
# Text(0.5,1,'Roughness as Func. of Deposition Rates')

# %% [markdown]
# # Reinforcement Learning Trial

# %%
#Set up the neural network model. Input: atom position box. Output: Choose out of 5 deposition rates ([0.05, 0.1, 0.15, 0.20, 0.25])
from keras import Sequential
from keras.layers import InputLayer, Dense, Conv3D, MaxPool3D, Flatten
from keras.optimizers import SGD

model = Sequential()
model.add(Conv3D(32, activation='relu', kernel_size = (3,3,3), strides = (1,1,1), batch_input_shape=(1,32,32,12,1)))
model.add(MaxPool3D((2,2,2)))
model.add(Conv3D(16, activation='relu', kernel_size = (3,3,3), strides = (1,1,1)))
#model.add(Conv3D(8, activation='relu', kernel_size = (3,3,3), strides = (1,1,1)))
model.add(MaxPool3D((2,2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(4, activation='linear'))
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
model.build()
model.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (1, 30, 30, 10, 32)       896
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (1, 15, 15, 5, 32)        0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (1, 13, 13, 3, 16)        13840
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (1, 6, 6, 1, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (1, 576)                  0
# _________________________________________________________________
# dense_1 (Dense)              (1, 128)                  73856
# _________________________________________________________________
# dense_2 (Dense)              (1, 128)                  16512
# _________________________________________________________________
# dense_3 (Dense)              (1, 4)                    516
# =================================================================
# Total params: 105,620
# Trainable params: 105,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_episodes = 150
y = 0.40
eps = 0.8
decay_factor = 0.99
r_avg_list = []
dep_rates = [0.10, 0.20, 0.30, 0.40]
diff_rates = [0.12, 0.14, 0.16, 0.18]
all_rates = [0.10, 0.20, 0.30, 0.40, 0.12, 0.14, 0.16, 0.18]
action_chosen = []

s = RunSim()
s.read(os.path.join(wdir,'kmc.input')) #Initialize the simulation with this input
    
for episode in range(num_episodes):
    if episode%5==0:
        print('Episode No. {}'.format(episode))
        
    counter = 0
    r_sum = 0
   
    #for each episode start from the beginning, i.e. initialize a new simulation with default parameters
    
    s.init_sim()
    end_flag = s.run_to_next_step(random_seed = np.random.randint(1,99)) #Run the simulation from the initial conditions
    
    while end_flag!=1:
        t0 = time()
        eps *= decay_factor
        #eps = max(eps, 0.05) #maintain some semblence of exploration ;)
        #Get the state and reward
        state, reward  = get_state_reward(s)

        #Choose an action
        if np.random.random() < eps:
            action = np.random.randint(0, 4)
        else:
            action = np.argmax(model.predict(state[None,:,:,:,None]))

        #Now run the simulation from the new state with the new action
        #Returns the state function and kmcmodel
        old_rates = s.kmc.etree.rates
        s_new, reward_new, kmc_model, end_flag = run_sim_with_chosen_action(s,action,old_rates, dep_rates)
        
        reward_new = reward_new - reward 
        
        target = reward_new + y * np.max(model.predict(s_new[None,:,:,:,None]))
        target_vec = model.predict(state[None,:,:,:,None])[0]
        target_vec[action] = target
        
        #print("Action Number: {}, Deposition Rate: {}".format(counter, dep_rates[action]))
        
        model.fit(state[None,:,:,:,None], target_vec.reshape(-1, 4), epochs=1, verbose=0)
        s = kmc_model
        counter+=1
        r_sum += reward_new
        
        t1 = time()
        action_chosen.append(action)
        #print("Took {} s".format(np.round(t1-t0, 4)))
        
    r_avg_list.append(r_sum)
# Out:
# Episode No. 0
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 5
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 10
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 15
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 20
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 25
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 30
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 35
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 40
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 45
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 50
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 55
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 60
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 65
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 70
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 75
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 80
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 85
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 90
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 95
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 100
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 105
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 110
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 115
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 120
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 125
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 130
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 135
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 140
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# Episode No. 145
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))
# ('Number of events:', array([512,   0]))

# %%
from scipy.signal import wiener, medfilt

kernel_size = 11

plt.figure(figsize = (12,8))
plt.plot(medfilt(r_avg_list, kernel_size= kernel_size)[kernel_size:-kernel_size], linewidth = 4)
plt.title('Agent Training: Deposition Rate', fontsize = 18)
plt.xlabel('Episode #', fontsize = 18)
plt.ylabel('Reward (Negative RMS Roughness)', fontsize = 18)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.savefig('reward_per_episode_dep.png', dpi = 300)

#Let's take a look at how the actions change over time: consider 9 increments

total_actions = len(action_chosen)
segments = np.linspace(0,total_actions, 10)

fig, axes = plt.subplots(nrows=3,ncols=3, figsize=(10,10))
for ind, ax in enumerate(axes.flat):
    seg_start = int(segments[ind])
    seg_finish = min(int(segments[ind+1]),total_actions)
    act_segment = action_chosen[seg_start:seg_finish]    
    ax.hist(act_segment, bins = [0,1,2,3,4])
    ax.set_xlabel('Dep Rate', fontsize = 14)
    ax.set_ylabel('Frequency', fontsize = 14)
    ax.set_title('Actions {} to {}'.format(seg_start, seg_finish), fontsize = 12 )
    ax.set_xticks([0.5,1.5,2.5,3.5])
    ax.set_xticklabels(dep_rates)

fig.suptitle('Actions Histogram', fontsize = 18, y = 1.05)
fig.tight_layout()
fig.savefig('actions_histogram_dep.png', dpi = 300)

# %%
len(r_avg_list)
# Out:
# 50

# %%
# Run the simulator with different values of the rates to establish baseline performance

# %%
#Get some average Q values from different states 


q_predictions = []
drates = [0.16, 0.18, 0.20]

for k in range(3):

    sim = RunSim()
    sim.read(os.path.join(wdir,'kmc.input'))
    sim.init_sim()
    sim.update_rate(np.array([drates[k], deprates[k]]))
    for ind in range(5):
        sim.run_to_next_step()
        arr = sim.kmc.get_conf()
        arr_1 = np.array(arr[0])
        full_atom_box = np.zeros([latt['box'][1],latt['box'][2],latt['box'][3] ])
        for i,j,k in arr_1:
            full_atom_box[i,j,k]=1
        q_predictions.append(model.predict(full_atom_box[None,:,:,:,None]))
# Out:
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.1 ]
# ('kmc step:', 0)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.2  0.14]
# ('kmc step:', 0)

# %%
for q in q_predictions: print(np.round(q[0],3))
# Out:
# [-0.08  -0.254 -0.186 -0.275]
# [-0.024 -0.176 -0.133 -0.225]
# [-0.019 -0.163 -0.129 -0.22 ]
# [-0.018 -0.163 -0.129 -0.22 ]
# [-0.019 -0.162 -0.128 -0.22 ]
# [-0.069 -0.246 -0.176 -0.272]
# [-0.024 -0.172 -0.132 -0.226]
# [-0.019 -0.165 -0.129 -0.22 ]
# [-0.018 -0.162 -0.129 -0.218]
# [-0.019 -0.16  -0.128 -0.219]
# [-0.059 -0.223 -0.163 -0.256]
# [-0.02  -0.169 -0.131 -0.224]
# [-0.02  -0.163 -0.129 -0.219]
# [-0.017 -0.162 -0.128 -0.219]
# [-0.019 -0.163 -0.128 -0.22 ]

# %%
dep_rates = [0.12, 0.14, 0.16, 0.18]
diff_rates = [0.12, 0.14, 0.16, 0.18]

sim_results_meaned = np.zeros((4,4,2))

for row, dep_rate in enumerate(dep_rates):
    for col, diff_rate in enumerate(diff_rates):
        sim_results= []
        for k in range(10):
            s = RunSim()
            s.read(os.path.join(wdir,'kmc.input')) #Initialize the simulation with this input   
            s.init_sim()
            new_rates = np.array([dep_rate, diff_rate])
            s.update_rate(new_rates)
            s.run();
            _, reward  = get_state_reward(s)
            sim_results.append(reward)
        sim_results_meaned[row,col,:] = [np.mean(sim_results), np.std(sim_results)]
        print('Completed ({},{}) of 16'.format(row,col))
# Out:
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.00001378733233, 4218, 3582)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.002706157086156, 4165, 3541)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.00703665898766, 4191, 3568)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.005375799200344, 4291, 3557)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.001689883509314, 4026, 3522)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.013980936440067, 4074, 3499)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.01631628508143, 4204, 3588)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.010621994607785, 4236, 3609)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.00094233493142, 4148, 3539)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.12]
# ('kmc step:', 0)
# (30.001893292663453, 4072, 3564)
# Completed (0,0) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.0034684831214, 4567, 3543)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.00059566805432, 4656, 3603)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.003708887264008, 4537, 3542)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.01806356325297, 4352, 3527)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.021176309048574, 4488, 3546)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.002628547273964, 4365, 3481)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.005789884774686, 4618, 3573)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.001659435988863, 4423, 3524)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.00983006807516, 4661, 3615)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.14]
# ('kmc step:', 0)
# (30.00085451493659, 4627, 3570)
# Completed (0,1) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.001716725572557, 5082, 3693)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.004671864166433, 4709, 3502)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.003441320598565, 4496, 3490)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.000682758507867, 4740, 3456)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.005359232760863, 4809, 3537)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.008558604051306, 4675, 3473)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.00522731353016, 4608, 3517)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.0094127805208, 4737, 3479)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.006062292339898, 4644, 3477)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.16]
# ('kmc step:', 0)
# (30.018756316031055, 4754, 3528)
# Completed (0,2) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.000938292435958, 5207, 3559)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.00472698718794, 5143, 3513)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.00608924517772, 5324, 3545)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.001430220965208, 5064, 3492)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.00310076488174, 5095, 3492)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.005379132551194, 5205, 3514)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.003711986298235, 5130, 3503)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.004924382625337, 5181, 3515)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.00566065293808, 5180, 3522)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.12 0.18]
# ('kmc step:', 0)
# (30.006725118538, 5093, 3474)
# Completed (0,3) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.00454173473086, 4629, 3840)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.001266857375875, 4815, 3908)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.00151626377348, 4834, 3924)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.00131762630091, 4901, 3951)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.000227048244692, 4784, 3875)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.0077387830832, 4804, 3928)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.00653543118605, 4402, 3762)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.00139620359577, 4654, 3876)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.013982203558722, 4578, 3879)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.12]
# ('kmc step:', 0)
# (30.002863988925377, 4649, 3865)
# Completed (1,0) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.002229097575167, 4952, 3769)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.004207493358674, 4925, 3814)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.005724303490318, 4835, 3817)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.00663797895658, 4944, 3838)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.02170517615473, 5016, 3858)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.00773874111633, 4931, 3840)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.00625110442274, 5108, 3925)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.007488389078596, 5142, 3858)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.001003978771088, 4929, 3823)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.14]
# ('kmc step:', 0)
# (30.00138005497641, 5055, 3857)
# Completed (1,1) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.008099911272012, 5203, 3775)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.00210941690775, 5203, 3792)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.005205290022232, 5531, 3847)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.003428511288586, 5238, 3784)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.001041117978502, 5303, 3841)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.003824370735707, 5036, 3710)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.003663682935002, 5253, 3771)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.003165229107132, 5288, 3794)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.001463268446447, 5335, 3811)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.16]
# ('kmc step:', 0)
# (30.00070519229438, 5229, 3839)
# Completed (1,2) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.019333916297256, 5673, 3778)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.005976234128504, 5464, 3734)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.003125438707237, 5422, 3813)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.009699508669986, 5868, 3900)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.00263957431972, 5521, 3767)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.018274599721998, 5411, 3729)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.002501584554444, 5534, 3738)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.00100606787934, 5854, 3869)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.01035928348333, 5514, 3724)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.14 0.18]
# ('kmc step:', 0)
# (30.01878479989512, 5698, 3819)
# Completed (1,3) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.010179176476967, 5062, 4100)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.004872455836278, 5293, 4200)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.022250681346055, 5203, 4208)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.00313440689991, 5122, 4067)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.002705811734344, 5042, 4134)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.008338892706725, 4978, 3990)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.009004503204224, 5132, 4138)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.000604227274778, 5194, 4144)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.002603011692724, 5320, 4226)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.12]
# ('kmc step:', 0)
# (30.004751722614113, 5022, 4031)
# Completed (2,0) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.003113704815213, 5467, 4080)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.001066209808986, 5409, 4072)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.006361911027255, 5601, 4212)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.003743232747084, 5429, 4101)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.004775239767476, 5485, 4098)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.0004899054528, 5416, 4139)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.00755909117548, 5344, 4066)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.00478228423741, 5301, 4100)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.00565520768395, 5641, 4169)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.14]
# ('kmc step:', 0)
# (30.001696068235347, 5673, 4249)
# Completed (2,1) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.005614758700833, 5694, 4060)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.001006929927225, 5895, 4173)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.002169799895512, 5873, 4094)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.00439935327957, 5491, 3985)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.003342400225005, 5755, 4064)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.003299162168094, 5791, 4084)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.00304213001621, 5655, 4033)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.000121654811124, 5919, 4141)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.010721656099964, 5661, 4104)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.16]
# ('kmc step:', 0)
# (30.003385983605067, 5702, 4047)
# Completed (2,2) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.00390472890426, 5931, 4028)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.001542222077813, 6164, 4020)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.001792891160413, 6268, 4139)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.002115461977155, 5986, 4019)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.00034372565179, 6079, 4070)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.00241759137419, 6319, 4117)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.006115358199622, 6094, 4052)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.003624774687584, 6052, 4104)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.004743578556024, 6148, 4053)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.16 0.18]
# ('kmc step:', 0)
# (30.0088594707843, 5996, 4027)
# Completed (2,3) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.00661144809259, 5634, 4417)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.000609324747053, 5640, 4475)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.00617839145443, 5791, 4478)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.00073876996096, 5584, 4498)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.00293639740573, 5539, 4422)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.000684006581047, 5592, 4463)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.003217207508552, 5864, 4590)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.004489652958686, 5678, 4497)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.001995672691557, 5442, 4366)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.12]
# ('kmc step:', 0)
# (30.003568623123385, 5525, 4402)
# Completed (3,0) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.003473063229865, 5770, 4375)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.00223171797724, 5997, 4489)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.008423868492134, 5905, 4373)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.009280428165294, 5882, 4408)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.002441165328396, 5945, 4445)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.001046651115693, 5987, 4421)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.006569177912237, 6040, 4439)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.003117371192815, 6083, 4414)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.000800693947077, 6204, 4544)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.14]
# ('kmc step:', 0)
# (30.00054814271899, 5886, 4374)
# Completed (3,1) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.00037369789551, 6055, 4369)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.004030224000463, 6344, 4359)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.007234368897915, 6124, 4330)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.000248312912127, 6490, 4519)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.003754089034295, 6159, 4308)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.008738169152586, 6300, 4416)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.003551914988183, 6277, 4388)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.00276739751796, 6306, 4354)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.00037914995108, 6282, 4291)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.16]
# ('kmc step:', 0)
# (30.00398010699302, 6141, 4339)
# Completed (3,2) of 16
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.004739747023645, 6715, 4407)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.00279365153865, 6542, 4412)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.00144874271314, 6584, 4371)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.000907919696942, 6518, 4364)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.008146506923833, 6646, 4353)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.006509042940998, 6573, 4310)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.001255969175208, 6624, 4423)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.003384999367718, 6593, 4354)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.000272810746008, 6692, 4369)
# ('Number of events:', array([512,   0]))
# current rates:[0.1 0.1]
# new rates:[0.18 0.18]
# ('kmc step:', 0)
# (30.000201276178277, 6527, 4358)
# Completed (3,3) of 16

# %%
plt.figure()
plt.imshow(sim_results_meaned[:,:,0])
plt.colorbar(label = '-1*Roughness RMS')
plt.xticks([0,1,2,3], diff_rates, fontsize = 14)
plt.yticks([0,1,2,3],dep_rates, fontsize = 14)
plt.xlabel('Diffusion Rates', fontsize = 18)
plt.ylabel('Deposition Rates', fontsize = 18)
plt.title('Mean of 10 runs', fontsize = 18)

plt.figure()
plt.imshow(sim_results_meaned[:,:,1])
plt.colorbar(label = '-Std. Dev. of Reward')
plt.xticks([0,1,2,3], diff_rates, fontsize = 14)
plt.yticks([0,1,2,3],dep_rates, fontsize = 14)
plt.xlabel('Diffusion Rates', fontsize = 18)
plt.ylabel('Deposition Rates', fontsize = 18)
plt.title('Stdev of 30 runs', fontsize = 18)
# Out:
# Text(0.5,1,'Stdev of 30 runs')

# %% [markdown]
# #### things to try
# #1. 2d conv net with surface projection
# #2. flattened array with xyz values instead of whole box
# #3. find time taken per simulation (as above)
#
# 1. distributed learning.
# 2. try more sophisticated algo.
# 3. keep on getting closer to PLD...
